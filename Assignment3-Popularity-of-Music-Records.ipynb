# %%
import pandas as pd

# %%
songs = pd.read_csv("/Users/rio512hsu/Downloads/songs.csv", encoding="latin-1")

# %%
songs.columns
# Out:
# Index(['year', 'songtitle', 'artistname', 'songID', 'artistID',
#        'timesignature', 'timesignature_confidence', 'loudness', 'tempo',
#        'tempo_confidence', 'key', 'key_confidence', 'energy', 'pitch',
#        'timbre_0_min', 'timbre_0_max', 'timbre_1_min', 'timbre_1_max',
#        'timbre_2_min', 'timbre_2_max', 'timbre_3_min', 'timbre_3_max',
#        'timbre_4_min', 'timbre_4_max', 'timbre_5_min', 'timbre_5_max',
#        'timbre_6_min', 'timbre_6_max', 'timbre_7_min', 'timbre_7_max',
#        'timbre_8_min', 'timbre_8_max', 'timbre_9_min', 'timbre_9_max',
#        'timbre_10_min', 'timbre_10_max', 'timbre_11_min', 'timbre_11_max',
#        'Top10'],
#       dtype='object')

# %%
songs[songs['year'] == 2010].shape
# Out:
# (373, 39)

# %%
songs[songs['artistname'] == "Michael Jackson"].shape
# Out:
# (18, 39)

# %%
jackson = songs[songs['artistname'] == "Michael Jackson"]
jackson[jackson['Top10'] == True]
# Out:
#       year          songtitle       artistname              songID  \
# 4328  2001  You Rock My World  Michael Jackson  SOBLCOF13134393021
# 6206  1995  You Are Not Alone  Michael Jackson  SOJKNNO13737CEB162
# 6209  1995     Black or White  Michael Jackson  SOBBRFO137756C9CB7
# 6217  1995  Remember the Time  Michael Jackson  SOIQZMT136C9704DA5
# 6914  1992      In The Closet  Michael Jackson  SOKIOOC12AF729ED9E
#
#                 artistID  timesignature  timesignature_confidence  loudness  \
# 4328  ARXPPEY1187FB51DF4              4                     1.000    -2.768
# 6206  ARXPPEY1187FB51DF4              4                     1.000    -9.408
# 6209  ARXPPEY1187FB51DF4              4                     1.000    -4.017
# 6217  ARXPPEY1187FB51DF4              4                     1.000    -3.633
# 6914  ARXPPEY1187FB51DF4              4                     0.991    -4.315
#
#         tempo  tempo_confidence  ...    timbre_7_max  timbre_8_min  \
# ...

# %%
songs['timesignature'].value_counts()
# Out:
# 4    6787
# 3     503
# 1     143
# 5     112
# 7      19
# 0      10
# Name: timesignature, dtype: int64

# %%
songs.sort_values(by='tempo', ascending=False)
# Out:
#       year                              songtitle  \
# 6205  1995            Wanna Be Startin' Somethin'
# 5945  1996                       Zodijackyl Light
# 4090  2002               You're a Fucking Bastard
# 1185  2008                             Relentless
# 4759  2000                 The Chainheart Machine
# 1200  2008                                Take It
# 2895  2004                    Holiday in Cambodia
# 3518  2003                              Interlude
# 7003  1992              Gotta Kill Captain Stupid
# 2931  2004                   Like You Better Dead
# 3519  2003                            The Promise
# 4703  2000                 Passage to Pandemonium
# 1448  2007                      Raping the System
# 7347  1990                             Painkiller
# 48    2010                  The Demiurge Molecule
# 3990  2002                   Instinct of Survival
# 7405  1990                 Giving You The Benefit
# 3316  2003                    Blue Ridge Laughing
# ...

# %%
train = songs[songs['year'] <= 2009].copy()
test = songs[songs['year'] > 2009].copy()

# %%
train.shape
# Out:
# (7201, 39)

# %%
import statsmodels.formula.api as sm

# %%
columns = songs.columns.tolist()
novars = set(["Top10", "year", "songtitle", "artistname", "songID", "artistID"])
columns = [c for c in columns if not c in novars]
print(columns)
# Out:
# ['timesignature', 'timesignature_confidence', 'loudness', 'tempo', 'tempo_confidence', 'key', 'key_confidence', 'energy', 'pitch', 'timbre_0_min', 'timbre_0_max', 'timbre_1_min', 'timbre_1_max', 'timbre_2_min', 'timbre_2_max', 'timbre_3_min', 'timbre_3_max', 'timbre_4_min', 'timbre_4_max', 'timbre_5_min', 'timbre_5_max', 'timbre_6_min', 'timbre_6_max', 'timbre_7_min', 'timbre_7_max', 'timbre_8_min', 'timbre_8_max', 'timbre_9_min', 'timbre_9_max', 'timbre_10_min', 'timbre_10_max', 'timbre_11_min', 'timbre_11_max']

# %%
st = "+".join(columns)
SongsLog1 = sm.logit(formula="Top10 ~ " + st, data=train).fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.330451
#          Iterations 8

# %%
SongsLog1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:                  Top10   No. Observations:                 7201
# Model:                          Logit   Df Residuals:                     7167
# Method:                           MLE   Df Model:                           33
# Date:                Mon, 09 May 2016   Pseudo R-squ.:                  0.2091
# Time:                        18:30:12   Log-Likelihood:                -2379.6
# converged:                       True   LL-Null:                       -3008.8
#                                         LLR p-value:                2.683e-243
# ...
#                                coef    std err          z      P>|z|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------------------
# Intercept                   14.7000      1.806      8.138      0.000        11.160    18.240
# ...

# %%
SongsLog1.summary2()
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                                Results: Logit
# ...
# Model:                  Logit               Pseudo R-squared:    0.209
# Dependent Variable:     Top10               AIC:                 4827.1541
# Date:                   2016-05-09 18:44    BIC:                 5061.1413
# No. Observations:       7201                Log-Likelihood:      -2379.6
# Df Model:               33                  LL-Null:             -3008.8
# Df Residuals:           7167                LLR p-value:         2.6834e-243
# Converged:              1.0000              Scale:               1.0000
# No. Iterations:         8.0000
# ----------------------------------------------------------------------------
#                           Coef.   Std.Err.    z     P>|z|   [0.025   0.975]
# ----------------------------------------------------------------------------
# Intercept                 14.7000   1.8064   8.1378 0.0000  11.1595  18.2404
# ...
